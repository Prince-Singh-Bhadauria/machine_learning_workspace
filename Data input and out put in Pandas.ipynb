# %%
import pandas as pd

# %%
pwd               # to get the location of pandas in directory
# Out:
# '/home/prince_singh/Desktop'

# %%
pd.read_csv('electronic-card-transactions-january-2021-csv-tables.csv')
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03      2462.5        NaN      F  Dollars
# 1           ECTA.S19A1  2002.03     17177.2        NaN      F  Dollars
# 2           ECTA.S19A1  2003.03     22530.5        NaN      F  Dollars
# 3           ECTA.S19A1  2004.03     28005.1        NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 17505       ECTQ.S4AXP  2019.12        43.6        NaN      F  Percent
# 17506       ECTQ.S4AXP  2020.03        42.6        NaN      F  Percent
# 17507       ECTQ.S4AXP  2020.06        36.3        NaN      F  Percent
# 17508       ECTQ.S4AXP  2020.09        39.2        NaN      F  Percent
# 17509       ECTQ.S4AXP  2020.12        38.6        NaN      F  Percent
#
#        Magnitude                                        Subject  \
# ...

# %%
df = pd.read_csv('electronic-card-transactions-january-2021-csv-tables.csv')

# %%
df2 = df.to_csv('new_name_electronic-card-transactions-january-2021-csv-tables.csv') #saving new file, in same location

# %%
 pd.read_excel('SampleData.xlsx')       # reading excel files
# Out:
#     Unnamed: 0 Unnamed: 1                                         Unnamed: 2
# 0          NaN        NaN                                                NaN
# 1          NaN        NaN                                                NaN
# 2          NaN        NaN                                                NaN
# 3          NaN        NaN                            Online Instruction Page
# 4          NaN        NaN                              Sample Data for Excel
# 5          NaN        NaN                                                NaN
# 6          NaN        NaN                                  Related tutorials
# 7          NaN        NaN                                 Named Excel Tables
# 8          NaN        NaN                                    Data Entry Tips
# 9          NaN        NaN                            More Excel Sample Files
# 10         NaN        NaN                                                NaN
# ...

# %%
df4 = pd.read_html('https://www.contextures.com/xlsampledata01.html')    #reading html file

# %%
df4[0]                                                            # DataFrame of html file
# Out:
#              0        1         2        3      4         5        6
# 0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1     1/6/2019     East     Jones   Pencil     95      1.99   189.05
# 2    1/23/2019  Central    Kivell   Binder     50     19.99   999.50
# 3     2/9/2019  Central   Jardine   Pencil     36      4.99   179.64
# 4    2/26/2019  Central      Gill      Pen     27     19.99   539.73
# 5    3/15/2019     West   Sorvino   Pencil     56      2.99   167.44
# 6     4/1/2019     East     Jones   Binder     60      4.99   299.40
# 7    4/18/2019  Central   Andrews   Pencil     75      1.99   149.25
# 8     5/5/2019  Central   Jardine   Pencil     90      4.99   449.10
# 9    5/22/2019     West  Thompson   Pencil     32      1.99    63.68
# 10    6/8/2019     East     Jones   Binder     60      8.99   539.40
# 11   6/25/2019  Central    Morgan   Pencil     90      4.99   449.10
# 12   7/12/2019     East    Howard   Binder     29      1.99    57.71
# ...

# %%
from sqlalchemy import create_engine                                     # importing Sql package
engine = create_engine('sqlite:///:memory:')                        # creating a temporary engine in memory for sql

# %%
df_sql = df4[0].to_sql('My_SQL_Table', engine)                     #saving html dataframe to sql data

# %%
pd.read_sql('My_SQL_Table', con = engine)                           # reading sql data
# Out:
#     index           0        1         2        3      4         5        6
# 0       0   OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1       1    1/6/2019     East     Jones   Pencil     95      1.99   189.05
# 2       2   1/23/2019  Central    Kivell   Binder     50     19.99   999.50
# 3       3    2/9/2019  Central   Jardine   Pencil     36      4.99   179.64
# 4       4   2/26/2019  Central      Gill      Pen     27     19.99   539.73
# 5       5   3/15/2019     West   Sorvino   Pencil     56      2.99   167.44
# 6       6    4/1/2019     East     Jones   Binder     60      4.99   299.40
# 7       7   4/18/2019  Central   Andrews   Pencil     75      1.99   149.25
# 8       8    5/5/2019  Central   Jardine   Pencil     90      4.99   449.10
# 9       9   5/22/2019     West  Thompson   Pencil     32      1.99    63.68
# 10     10    6/8/2019     East     Jones   Binder     60      8.99   539.40
# ...
